# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
connection = MongoClient()

# %%
# assign the uk_food database to a variable name
db = connection['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments_coll', 'establishments']

# %%
# assign the collection to a variable
establishments = food_db['establishments']

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('680edc7b14dca42d61da16a9'),
#  'BusinessName': 'The Food Place',
#  'BusinessType': 'Restaurant',
#  'BusinessTypeID': 12345,
#  'AddressLine1': '123 Food St',
#  'AddressLine2': '',
#  'AddressLine3': '',
#  'PostCode': 'AB12 3CD',
#  'Phone': '01234 567890',
#  'RatingValue': 5,
#  'RatingKey': 5,
#  'RatingDate': '2023-10-01',
#  'longitude': None,
#  'latitude': None,
#  'geocode': {'latitude': None, 'longitude': None}}

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query_hygiene_20 = {"scores.Hygiene": 20}
hygiene_20_results = list(establishments.find(query_hygiene_20))
print(f"Matches found: {len(hygiene_20_results)}")
pprint(hygiene_20_results[0])
# Out:
# Matches found: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('684379721075b067377d469e'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
# ...

# %%
# Convert the result to a Pandas DataFrame
df_hygiene_20 = pd.DataFrame(hygiene_20_results)
df_hygiene_20.head()
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  684379721075b067377d469e  110681                  0
# 1  684379721075b067377d4a1b  612039                  0
# 2  684379721075b067377d4d29  730933                  0
# 3  684379721075b067377d4f17  172735                  0
# 4  684379721075b067377d4f2a  172953                  0
#
#   LocalAuthorityBusinessID         BusinessName  \
# 0                     4029  The Chase Rest Home
# 1                1970/FOOD           Brenalwood
# 2                1698/FOOD        Melrose Hotel
# 3             PI/000023858        Seaford Pizza
# 4             PI/000024532        Golden Palace
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# ...

# %%
query = {'LocalAuthorityName': 'London'}
hygiene_20_results = establishments.find(query)
print(establishments.count_documents(query))
for result in hygiene_20_results:
    pprint(result)
# Out:
# 0

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find establishments in London with RatingValue >= 4
query = {
    'LocalAuthorityName': 'London',
    'RatingValue': {'$gte': 4}
}
hygiene_20_results = establishments.find(query)
print(establishments.count_documents(query))
for result in hygiene_20_results:
    pprint(result)
# Out:
# 0

# %%
# Convert the result to a Pandas DataFrame
df_london_rating = pd.DataFrame(london_rating_results)
df_london_rating.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#grabbing latitude and longitude from Penang Flavours
query = {'BusinessName': 'Penang Flavours'}
projection = {'geocode': 1}

result = list(establishments.find(query, projection))
pprint(result)
# Out:
# [{'_id': ObjectId('680edfe314dca42d61da16aa'),
#   'geocode': {'latitude': 51.490142, 'longitude': 0.08384}},
#  {'_id': ObjectId('680ee3a014dca42d61da16ab'),
#   'geocode': {'latitude': 51.490142, 'longitude': 0.08384}},
#  {'_id': ObjectId('6843884ed0b2486171ee0126'),
#   'geocode': {'latitude': 51.490142, 'longitude': 0.08384}},
#  {'_id': ObjectId('684389aad0b2486171ee0127'),
#   'geocode': {'latitude': 51.490142, 'longitude': 0.08384}}]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Get Penang Flavours coordinates and search nearby
degree_search = 0.01
latitude = 51.490142
longitude = 0.08384

query = {
        'geocode.latitude' : {'$gte' : latitude - degree_search, '$lte' : latitude + degree_search}, 
        'geocode.longitude': {'$gte' : longitude - degree_search, '$lte' : longitude + degree_search},
        'RatingValue' : {'$eq' : 5}
        }
sort = [('scores.Hygiene', 1)]
limit = 5


# Print the results
results = list(establishments.find(query).sort(sort).limit(limit))
pprint(results)
# Out:
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('684379721075b067377d9efe'),
#   'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
# ...

# %%
# Convert result to Pandas DataFrame
df_nearby = pd.DataFrame(top_nearby)
df_nearby.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
match_q = {'$match' : {'scores.Hygiene' : {'$eq' : 0}}}

# 2. Groups the matches by Local Authority
group_q = {'$group' : {'_id' : '$LocalAuthorityName',
           'count' : {'$sum' : 1}}}

#3. Sorts the matches from highest to lowest
sort = {'$sort' : {'count' : -1}}

pipeline = [match_q, group_q, sort]
results = list(establishments_coll.aggregate(pipeline))



pipeline = [match_q, group_q, sort]
results = list(establishments_coll.aggregate(pipeline))
# Print the number of documents in the result
print(f'# of docs in results: {len(results)}')
      
# Print the first 10 results
print(results[0:10])
# Out:
# # of docs in results: 55
# [{'_id': 'Thanet', 'count': 1130}, {'_id': 'Greenwich', 'count': 882}, {'_id': 'Maidstone', 'count': 713}, {'_id': 'Newham', 'count': 711}, {'_id': 'Swale', 'count': 686}, {'_id': 'Chelmsford', 'count': 680}, {'_id': 'Medway', 'count': 672}, {'_id': 'Bexley', 'count': 607}, {'_id': 'Southend-On-Sea', 'count': 586}, {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
agg_df = pd.DataFrame(agg_results)
agg_df.head()
# Out:
#          _id  count
# 0     Thanet   1130
# 1  Greenwich    882
# 2  Maidstone    713
# 3     Newham    711
# 4      Swale    686
